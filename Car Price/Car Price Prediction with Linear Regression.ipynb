# %%
#importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' #for making my plots sharper
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression as lr
from sklearn import metrics
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
car_data = pd.read_csv("car data.csv")

# %%
#Summarizing the dataset, both the numerical and categorical features
from summarytools import dfSummary
dfSummary(car_data)
# Out:
# <style type="text/css">
# #T_32a7e thead>tr>th {
#   text-align: left;
# }
# #T_32a7e_row0_col0, #T_32a7e_row1_col0, #T_32a7e_row2_col0, #T_32a7e_row3_col0, #T_32a7e_row4_col0, #T_32a7e_row5_col0, #T_32a7e_row6_col0, #T_32a7e_row7_col0, #T_32a7e_row8_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_32a7e_row0_col1, #T_32a7e_row1_col1, #T_32a7e_row2_col1, #T_32a7e_row3_col1, #T_32a7e_row4_col1, #T_32a7e_row5_col1, #T_32a7e_row6_col1, #T_32a7e_row7_col1, #T_32a7e_row8_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_32a7e_row0_col2, #T_32a7e_row1_col2, #T_32a7e_row2_col2, #T_32a7e_row3_col2, #T_32a7e_row4_col2, #T_32a7e_row5_col2, #T_32a7e_row6_col2, #T_32a7e_row7_col2, #T_32a7e_row8_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_32a7e_row0_col3, #T_32a7e_row1_col3, #T_32a7e_row2_col3, #T_32a7e_row3_col3, #T_32a7e_row4_col3, #T_32a7e_row5_col3, #T_32a7e_row6_col3, #T_32a7e_row7_col3, #T_32a7e_row8_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_32a7e_row0_col4, #T_32a7e_row1_col4, #T_32a7e_row2_col4, #T_32a7e_row3_col4, #T_32a7e_row4_col4, #T_32a7e_row5_col4, #T_32a7e_row6_col4, #T_32a7e_row7_col4, #T_32a7e_row8_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_32a7e_row0_col5, #T_32a7e_row1_col5, #T_32a7e_row2_col5, #T_32a7e_row3_col5, #T_32a7e_row4_col5, #T_32a7e_row5_col5, #T_32a7e_row6_col5, #T_32a7e_row7_col5, #T_32a7e_row8_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_32a7e">
#   <caption><strong>Data Frame Summary</strong><br>car_data<br>Dimensions: 301 x 9<br>Duplicates: 2</caption>
#   <thead>
#     <tr>
#       <th id="T_32a7e_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_32a7e_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_32a7e_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_32a7e_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_32a7e_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_32a7e_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_32a7e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_32a7e_row0_col1" class="data row0 col1" ><strong>Car_Name</strong><br>[object]</td>
#       <td id="T_32a7e_row0_col2" class="data row0 col2" >1. city<br>2. corolla altis<br>3. verna<br>4. fortuner<br>5. brio<br>6. ciaz<br>7. innova<br>8. i20<br>9. grand i10<br>10. jazz<br>11. other</td>
#       <td id="T_32a7e_row0_col3" class="data row0 col3" >26 (8.6%)<br>16 (5.3%)<br>14 (4.7%)<br>11 (3.7%)<br>10 (3.3%)<br>9 (3.0%)<br>9 (3.0%)<br>9 (3.0%)<br>8 (2.7%)<br>7 (2.3%)<br>182 (60.5%)</td>
#       <td id="T_32a7e_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_32a7e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_32a7e_row1_col1" class="data row1 col1" ><strong>Year</strong><br>[int64]</td>
#       <td id="T_32a7e_row1_col2" class="data row1 col2" >Mean (sd) : 2013.6 (2.9)<br>min < med < max:<br>2003.0 < 2014.0 < 2018.0<br>IQR (CV) : 4.0 (696.4)</td>
#       <td id="T_32a7e_row1_col3" class="data row1 col3" >16 distinct values</td>
#       <td id="T_32a7e_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_32a7e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_32a7e_row2_col1" class="data row2 col1" ><strong>Selling_Price</strong><br>[float64]</td>
#       <td id="T_32a7e_row2_col2" class="data row2 col2" >Mean (sd) : 4.7 (5.1)<br>min < med < max:<br>0.1 < 3.6 < 35.0<br>IQR (CV) : 5.1 (0.9)</td>
#       <td id="T_32a7e_row2_col3" class="data row2 col3" >156 distinct values</td>
#       <td id="T_32a7e_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_32a7e_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_32a7e_row3_col1" class="data row3 col1" ><strong>Present_Price</strong><br>[float64]</td>
#       <td id="T_32a7e_row3_col2" class="data row3 col2" >Mean (sd) : 7.6 (8.6)<br>min < med < max:<br>0.3 < 6.4 < 92.6<br>IQR (CV) : 8.7 (0.9)</td>
#       <td id="T_32a7e_row3_col3" class="data row3 col3" >147 distinct values</td>
#       <td id="T_32a7e_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_32a7e_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_32a7e_row4_col1" class="data row4 col1" ><strong>Kms_Driven</strong><br>[int64]</td>
#       <td id="T_32a7e_row4_col2" class="data row4 col2" >Mean (sd) : 36947.2 (38886.9)<br>min < med < max:<br>500.0 < 32000.0 < 500000.0<br>IQR (CV) : 33767.0 (1.0)</td>
#       <td id="T_32a7e_row4_col3" class="data row4 col3" >206 distinct values</td>
#       <td id="T_32a7e_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_32a7e_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_32a7e_row5_col1" class="data row5 col1" ><strong>Fuel_Type</strong><br>[object]</td>
#       <td id="T_32a7e_row5_col2" class="data row5 col2" >1. Petrol<br>2. Diesel<br>3. CNG</td>
#       <td id="T_32a7e_row5_col3" class="data row5 col3" >239 (79.4%)<br>60 (19.9%)<br>2 (0.7%)</td>
#       <td id="T_32a7e_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_32a7e_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_32a7e_row6_col1" class="data row6 col1" ><strong>Seller_Type</strong><br>[object]</td>
#       <td id="T_32a7e_row6_col2" class="data row6 col2" >1. Dealer<br>2. Individual</td>
#       <td id="T_32a7e_row6_col3" class="data row6 col3" >195 (64.8%)<br>106 (35.2%)</td>
#       <td id="T_32a7e_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_32a7e_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_32a7e_row7_col1" class="data row7 col1" ><strong>Transmission</strong><br>[object]</td>
#       <td id="T_32a7e_row7_col2" class="data row7 col2" >1. Manual<br>2. Automatic</td>
#       <td id="T_32a7e_row7_col3" class="data row7 col3" >261 (86.7%)<br>40 (13.3%)</td>
#       <td id="T_32a7e_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_32a7e_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_32a7e_row8_col1" class="data row8 col1" ><strong>Owner</strong><br>[int64]</td>
#       <td id="T_32a7e_row8_col2" class="data row8 col2" >Mean (sd) : 0.0 (0.2)<br>min < med < max:<br>0.0 < 0.0 < 3.0<br>IQR (CV) : 0.0 (0.2)</td>
#       <td id="T_32a7e_row8_col3" class="data row8 col3" >3 distinct values</td>
#       <td id="T_32a7e_row8_col4" class="data row8 col4" ><img src = "......"></img></td>
#       <td id="T_32a7e_row8_col5" class="data row8 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
car_data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
fuel_type = car_data['Fuel_Type']
seller_type = car_data['Seller_Type']
transmission_type = car_data['Transmission']
selling_price = car_data['Selling_Price']

# %%
from matplotlib import style

# %%
#visualizing the categorical data with bar charts
style.use('ggplot') #Using the ggplot style adapted from R
fig = plt.figure(figsize=(15,5))
fig.suptitle('Visualizing Categorical Data Columns')
plt.subplot(1,3,1) #One row three columns, graph 1
plt.bar(fuel_type, selling_price, color='royalblue')
plt.xlabel('Fuel Type')
plt.ylabel('Selling Price')
plt.subplot(1,3,2) #graph 2
plt.bar(seller_type, selling_price, color='red')
plt.xlabel('Seller Type')
plt.subplot(1,3,3) #graph 3
plt.bar(transmission_type, selling_price, color='purple')
plt.xlabel('Transmission Type')
plt.show()

# %% [markdown]
# Visualising with matplotlib shows us only the max values.

# %%
#Visualizing with Seaborn
fig, axes = plt.subplots(1,3,figsize=(15,5), sharey=True)
fig.suptitle('Visualizing Categorical Columns')
sns.barplot(x=fuel_type, y=selling_price, ax=axes[0])
sns.barplot(x=seller_type, y=selling_price, ax=axes[1])
sns.barplot(x=transmission_type, y=selling_price, ax=axes[2])
# Out:
# <AxesSubplot:xlabel='Transmission', ylabel='Selling_Price'>
